# %%
import pandas as pd

# %%
df = pd.read_csv('서울시_버스정류장_좌표.CSV', encoding='cp949')
df
# Out:
#             노선ID   노선명        정류소명          경도         위도      행정동  \
# 0      100100124  0017     청암자이아파트  126.946517  37.534363   원효로제2동
# 1      100100124  0017  청암동강변삼성아파트  126.949304  37.533961   원효로제2동
# 2      100100124  0017       청심경로당  126.950449  37.533744   원효로제2동
# 3      100100124  0017    원효2동주민센터  126.950904  37.534278   원효로제2동
# 4      100100124  0017         산천동  126.953984  37.535420   원효로제2동
# ...          ...   ...         ...         ...        ...      ...
# 34650  106900002  중랑02       면목지구대  127.094202  37.587838     면목본동
# 34651  106900002  중랑02       새마을금고  127.097335  37.589118  면목제3.8동
# 34652  106900002  중랑02         공판장  127.099060  37.588522  면목제3.8동
# 34653  106900002  중랑02   진주빌라.바다약국  127.100669  37.587783  면목제3.8동
# 34654  106900002  중랑02   진로아파트앞.종점  127.101491  37.587650  면목제3.8동
#
#               행정동코드    법정동         법정동코드                     지번  오류코드 오류내용
# 0      1.117057e+09    청암동  1.117012e+09      서울특별시 용산구 청암동 109   NaN  NaN
# ...

# %%
dd = df.drop_duplicates(['경도', '위도'], keep='first')

# %%
dd.to_csv('서울시 버스정류장 중복 제거.csv', encoding='cp949')
